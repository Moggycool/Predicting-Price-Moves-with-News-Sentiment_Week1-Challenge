# %% [markdown]
# # Task-1: Exploratory Data Analysis (EDA)- Text Analysis

# %%
from load import DataLoader
from text_analysis import TextAnalysis

# Load preprocessed data
loader = DataLoader(r"D:\Python\Week-1\Data-Week-1\pre_processed_data.csv")
df = loader.load_data()

# Run text analysis
ta = TextAnalysis(df, text_column="headline", n_topics=6)
results = ta.full_analysis()

print("Top Keywords:")
print(results["keywords"])

print("\nDiscovered Topics:")
for topic, words in results["topics"].items():
    print(f"{topic}: {', '.join(words)}")
