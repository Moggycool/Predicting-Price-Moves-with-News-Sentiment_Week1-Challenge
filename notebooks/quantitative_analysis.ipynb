# %%
import pandas as pd
from quantitative_analysis import QuantitativeAnalysis

# Load your stock price data
df = pd.read_csv(r"D:\Python\Week-1\Data-Week-1\AAPL.csv")  # Example CSV with OHLCV
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

# Run Quantitative Analysis
qa = QuantitativeAnalysis(df, symbol="AAPL")
qa.full_analysis()
