# %%
from load import DataLoader
from time_analysis import TimeAnalysis

# Load preprocessed data
loader = DataLoader(r"D:\Python\Week-1\Data-Week-1\pre_processed_data.csv")
df = loader.load_data()

# Time-based analysis
ta = TimeAnalysis(df, date_column="date")

# 1) Publication frequency
freq = ta.publication_frequency()

# 2) Publishing time analysis
time_stats = ta.publishing_time_analysis()
